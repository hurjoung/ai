# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:90% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:12pt;}
div.text_cell_render.rendered_html{font-size:12pt;}
div.output {font-size:12pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:12pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:12px;}
</style>
"""))
# Out:
# <style>
# div.container{width:90% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:12pt;}
# div.text_cell_render.rendered_html{font-size:12pt;}
# div.output {font-size:12pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:12pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:12px;}
# </style>

# %%
import pandas as pd

# %% [markdown]
# # 1. cvs파일 전처리

# %%
suwan = pd.read_csv('C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202301_수원시.csv', sep=',')

# %%
group_names = list(suwan.card_tpbuz_nm_2.groupby())

# %%
# group_names = list(card_nm2.groups.keys())
group_names
# Out:
# ['건강/기호식품',
#  '건강/기호식품',
#  '건강/기호식품',
#  '건강/기호식품',
#  '건강/기호식품',
#  '건강/기호식품',
#  '건강/기호식품',
#  '건강/기호식품',
#  '건강/기호식품',
#  '선물/완구',
#  '선물/완구',
#  '선물/완구',
#  '선물/완구',
#  '선물/완구',
#  '선물/완구',
#  '선물/완구',
#  '선물/완구',
#  '선물/완구',
#  '선물/완구',
#  '스포츠/레져용품',
#  '스포츠/레져용품',
#  '스포츠/레져용품',
#  '스포츠/레져용품',
#  '스포츠/레져용품',
#  '스포츠/레져용품',
#  '스포츠/레져용품',
#  '스포츠/레져용품',
#  '스포츠/레져용품',
#  '스포츠/레져용품',
#  '스포츠/레져용품',
#  '스포츠/레져용품',
#  '스포츠/레져용품',
#  '스포츠/레져용품',
#  '스포츠/레져용품',
#  '스포츠/레져용품',
#  '스포츠/레져용품',
#  '스포츠/레져용품',
#  '스포츠/레져용품',
#  '스포츠/레져용품',
#  '스포츠/레져용품',
#  '스포츠/레져용품',
#  '스포츠/레져용품',
#  '스포츠/레져용품',
#  '스포츠/레져용품',
#  '스포츠/레져용품',
#  '스포츠/레져용품',
#  '스포츠/레져용품',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '음/식료품소매',
#  '의복/의류',
#  '의복/의류',
#  '의복/의류',
#  '의복/의류',
#  '의복/의류',
#  '의복/의류',
#  '의복/의류',
#  '의복/의류',
#  '의복/의류',
#  '의복/의류',
#  '의복/의류',
#  '의복/의류',
#  '의복/의류',
#  '의복/의류',
#  '의복/의류',
#  '의복/의류',
#  '의복/의류',
#  '의복/의류',
#  '의복/의류',
#  '의복/의류',
#  '인테리어/가정용품',
#  '인테리어/가정용품',
#  '인테리어/가정용품',
#  '인테리어/가정용품',
#  '인테리어/가정용품',
#  '인테리어/가정용품',
#  '인테리어/가정용품',
#  '인테리어/가정용품',
#  '인테리어/가정용품',
#  '인테리어/가정용품',
#  '인테리어/가정용품',
#  '인테리어/가정용품',
#  '인테리어/가정용품',
#  '인테리어/가정용품',
#  '인테리어/가정용품',
#  '인테리어/가정용품',
#  '인테리어/가정용품',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '종합소매점',
#  '차량관리/부품',
#  '차량관리/부품',
#  '차량관리/부품',
#  '차량관리/부품',
#  '차량관리/부품',
#  '차량관리/부품',
#  '차량관리/부품',
#  '악기/공예',
#  '악기/공예',
#  '패션잡화',
#  '패션잡화',
#  '패션잡화',
#  '패션잡화',
#  '패션잡화',
#  '패션잡화',
#  '패션잡화',
#  '패션잡화',
#  '패션잡화',
#  '패션잡화',
#  '패션잡화',
#  '패션잡화',
#  '패션잡화',
#  '패션잡화',
#  '패션잡화',
#  '패션잡화',
#  '제조/도매',
#  '제조/도매',
#  '제조/도매',
#  '제조/도매',
#  '제조/도매',
#  '제조/도매',
#  '제조/도매',
#  '제조/도매',
#  '제조/도매',
#  '제조/도매',
#  '미용서비스',
#  '미용서비스',
#  '미용서비스',
#  '미용서비스',
#  '미용서비스',
#  '미용서비스',
#  '미용서비스',
#  '미용서비스',
#  '미용서비스',
#  '미용서비스',
#  '미용서비스',
#  '미용서비스',
#  '미용서비스',
#  '미용서비스',
#  '미용서비스',
#  '미용서비스',
#  '미용서비스',
#  '미용서비스',
#  '미용서비스',
#  '미용서비스',
#  '미용서비스',
#  '미용서비스',
#  '미용서비스',
#  '세탁/가사서비스',
#  '세탁/가사서비스',
#  '세탁/가사서비스',
#  '세탁/가사서비스',
#  '세탁/가사서비스',
#  '세탁/가사서비스',
#  '세탁/가사서비스',
#  '세탁/가사서비스',
#  '수리서비스',
#  '수리서비스',
#  '수리서비스',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '연료판매',
#  '차량관리/서비스',
#  '차량관리/서비스',
#  '차량관리/서비스',
#  '차량관리/서비스',
#  '차량관리/서비스',
#  '차량관리/서비스',
#  '차량관리/서비스',
#  '차량관리/서비스',
#  '차량관리/서비스',
#  '차량관리/서비스',
#  '차량관리/서비스',
#  '차량관리/서비스',
#  '차량관리/서비스',
#  '차량관리/서비스',
#  '차량관리/서비스',
#  '차량관리/서비스',
#  '차량관리/서비스',
#  '차량관리/서비스',
#  '차량관리/서비스',
#  '차량관리/서비스',
#  '무점포서비스',
#  '무점포서비스',
#  '무점포서비스',
#  '무점포서비스',
#  '무점포서비스',
#  '무점포서비스',
#  '숙박',
#  '숙박',
#  '숙박',
#  '숙박',
#  '숙박',
#  '숙박',
#  '숙박',
#  '숙박',
#  '숙박',
#  '일반스포츠',
#  '일반스포츠',
#  '일반스포츠',
#  '일반스포츠',
#  '일반스포츠',
#  '일반스포츠',
#  '일반스포츠',
#  '일반스포츠',
#  '일반스포츠',
#  '일반스포츠',
#  '일반스포츠',
#  '일반스포츠',
#  '일반스포츠',
#  '일반스포츠',
#  '일반스포츠',
#  '일반스포츠',
#  '일반스포츠',
#  '일반스포츠',
#  '일반스포츠',
#  '일반스포츠',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '취미/오락',
#  '간이주점',
#  '간이주점',
#  '간이주점',
#  '간이주점',
#  '간이주점',
#  '간이주점',
#  '간이주점',
#  '간이주점',
#  '간이주점',
#  '간이주점',
#  '간이주점',
#  '간이주점',
#  '간이주점',
#  '간이주점',
#  '간이주점',
#  '간이주점',
#  '간이주점',
#  '간이주점',
#  '간이주점',
#  '간이주점',
#  '간이주점',
#  '간이주점',
#  '간이주점',
#  '간이주점',
#  '간이주점',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '고기요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '닭/오리요리',
#  '별식/퓨전요리',
#  '별식/퓨전요리',
#  '별식/퓨전요리',
#  '별식/퓨전요리',
#  '별식/퓨전요리',
#  '별식/퓨전요리',
#  '별식/퓨전요리',
#  '별식/퓨전요리',
#  '별식/퓨전요리',
#  '별식/퓨전요리',
#  '별식/퓨전요리',
#  '별식/퓨전요리',
#  '별식/퓨전요리',
#  '별식/퓨전요리',
#  '별식/퓨전요리',
#  '별식/퓨전요리',
#  '별식/퓨전요리',
#  '별식/퓨전요리',
#  '별식/퓨전요리',
#  '별식/퓨전요리',
#  '별식/퓨전요리',
#  '별식/퓨전요리',
#  '별식/퓨전요리',
#  '별식/퓨전요리',
#  '별식/퓨전요리',
#  '별식/퓨전요리',
#  '별식/퓨전요리',
#  '부페',
#  '부페',
#  '부페',
#  '부페',
#  '부페',
#  '분식',
#  '분식',
#  '분식',
#  '분식',
#  '분식',
#  '분식',
#  '분식',
#  '분식',
#  '분식',
#  '분식',
#  '분식',
#  '분식',
#  '분식',
#  '분식',
#  '분식',
#  '분식',
#  '분식',
#  '분식',
#  '분식',
#  '분식',
#  '분식',
#  '분식',
#  '분식',
#  '분식',
#  '분식',
#  '분식',
#  '분식',
#  '분식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '양식',
#  '유흥주점',
#  '유흥주점',
#  '일식/수산물',
#  '일식/수산물',
#  '일식/수산물',
#  '일식/수산물',
#  '일식/수산물',
#  '일식/수산물',
#  '일식/수산물',
#  '일식/수산물',
#  '일식/수산물',
#  '일식/수산물',
#  '일식/수산물',
#  '일식/수산물',
#  '일식/수산물',
#  '일식/수산물',
#  '일식/수산물',
#  '일식/수산물',
#  '일식/수산물',
#  '일식/수산물',
#  '일식/수산물',
#  '일식/수산물',
#  '일식/수산물',
#  '일식/수산물',
#  '일식/수산물',
#  '일식/수산물',
#  '일식/수산물',
#  '일식/수산물',
#  '일식/수산물',
#  '일식/수산물',
#  '일식/수산물',
#  '일식/수산물',
#  '일식/수산물',
#  '일식/수산물',
#  '일식/수산물',
#  '일식/수산물',
#  '일식/수산물',
#  '일식/수산물',
#  '일식/수산물',
#  '일식/수산물',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '제과/제빵/떡/케익',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '중식',
#  '커피/음료',
#  '커피/음료',
#  '커피/음료',
#  '커피/음료',
#  '커피/음료',
#  '커피/음료',
#  '커피/음료',
#  '커피/음료',
#  '커피/음료',
#  '커피/음료',
#  '커피/음료',
#  '커피/음료',
#  ...]

# %%
card2 = suwan.card_tpbuz_nm_2.unique()
card2
# Out:
# array(['건강/기호식품', '선물/완구', '스포츠/레져용품', '음/식료품소매', '의복/의류', '인테리어/가정용품',
#        '종합소매점', '차량관리/부품', '악기/공예', '패션잡화', '제조/도매', '미용서비스', '세탁/가사서비스',
#        '수리서비스', '연료판매', '차량관리/서비스', '무점포서비스', '숙박', '일반스포츠', '취미/오락',
#        '간이주점', '고기요리', '닭/오리요리', '별식/퓨전요리', '부페', '분식', '양식', '유흥주점',
#        '일식/수산물', '제과/제빵/떡/케익', '중식', '커피/음료', '패스트푸드', '한식', '기타교육',
#        '유아교육', '입시학원', '수의업', '사무/교육용품', '서적/도서', '화장품소매', '광고/인쇄/인화',
#        '사우나/휴게시설', '렌탈서비스', '독서실/고시원', '예체능계학원', '외국어학원', '의약/의료품',
#        '일반병원', '기타결제', '가전제품', '기타의료', '기업', '단체', '요가/단전/마사지', '음식배달서비스',
#        '특화병원', '공연관람', '인터넷쇼핑', '방문판매', '교통서비스', '기술/직업교육학원', '공공기관',
#        '회비/공과금', '전문서비스', '유아용품', '부동산', '가례서비스', '휴게소/대형업체', '문화서비스',
#        '보안/운송', '기타용품', '종합병원', '종교', '전시장', '방송/미디어', '여행/유학대행', '차량판매',
#        '금융상품/서비스', '자동차학원', '경기관람', '시스템/통신', '학교'], dtype=object)

# %%
suwan_d = suwan[suwan.card_tpbuz_nm_2=='음식배달서비스']

# %%
suwan_d.card_tpbuz_nm_1.unique()
# Out:
# array(['음식'], dtype=object)

# %%
suwan_c = suwan[suwan.card_tpbuz_nm_2=='커피/음료']
suwan_c.to_csv('C:/data/경기도_카드_소비_데이터/suwan_202301.csv')

# %%
suwan = pd.read_csv('C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202302_수원시.csv', sep=',')

# %%
suwan_c = suwan[suwan.card_tpbuz_nm_2=='커피/음료']
suwan_c.to_csv('C:/data/경기도_카드_소비_데이터/suwan_202302.csv')

# %%
for idx in range(1, 13, 1):
    num = f"{idx:02d}"
    fileNm1 = 'C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_2023{}_수원시.csv'.format(num)
    print(fileNm1)
    suwan = pd.read_csv(fileNm1, sep=',')
    suwan_c = suwan[suwan.card_tpbuz_nm_2=='커피/음료']
    fileNm2 = 'C:/data/경기도_카드_소비_데이터/suwan_2023{}.csv'.format(num)
    suwan_c.to_csv(fileNm2)
# Out:
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202301_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202302_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202303_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202304_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202305_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202306_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202307_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202308_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202309_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202310_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202311_수원시.csv

# %%
for idx in range(1, 13, 1):
    num = f"{idx:02d}"
    fileNm1 = 'C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_2024{}_수원시.csv'.format(num)
    print(fileNm1)
    suwan = pd.read_csv(fileNm1, sep=',')
    suwan_c = suwan[suwan.card_tpbuz_nm_2=='커피/음료']
    fileNm2 = 'C:/data/경기도_카드_소비_데이터/suwan_2024{}.csv'.format(num)
    suwan_c.to_csv(fileNm2)
# Out:
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202401_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202402_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202403_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202404_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202405_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202406_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202407_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202408_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202409_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202410_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202411_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202412_수원시.csv
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[25], line 5
#       3 fileNm1 = 'C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_2024{}_수원시.csv'.format(num)
#       4 print(fileNm1)
# ----> 5 suwan = pd.read_csv(fileNm1, sep=',')
#       6 suwan_c = suwan[suwan.card_tpbuz_nm_2=='커피/음료']
#       7 fileNm2 = 'C:/data/경기도_카드_소비_데이터/suwan_2024{}.csv'.format(num)
#
# File ~\anaconda3\envs\ml-dl-nlp\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\ml-dl-nlp\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\ml-dl-nlp\lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\envs\ml-dl-nlp\lib\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File ~\anaconda3\envs\ml-dl-nlp\lib\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\envs\ml-dl-nlp\lib\site-packages\pandas\io\parsers\readers.py:1753, in TextFileReader._make_engine(self, f, engine)
#    1750     raise ValueError(msg)
#    1752 try:
# -> 1753     return mapping[engine](f, **self.options)
#    1754 except Exception:
#    1755     if self.handles is not None:
#
# File ~\anaconda3\envs\ml-dl-nlp\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:79, in CParserWrapper.__init__(self, src, **kwds)
#      76     kwds.pop(key, None)
#      78 kwds["dtype"] = ensure_dtype_objs(kwds.get("dtype", None))
# ---> 79 self._reader = parsers.TextReader(src, **kwds)
#      81 self.unnamed_cols = self._reader.unnamed_cols
#      83 # error: Cannot determine type of 'names'
#
# File ~\anaconda3\envs\ml-dl-nlp\lib\site-packages\pandas\_libs\parsers.pyx:547, in pandas._libs.parsers.TextReader.__cinit__()
#
# File ~\anaconda3\envs\ml-dl-nlp\lib\site-packages\pandas\_libs\parsers.pyx:636, in pandas._libs.parsers.TextReader._get_header()
#
# File ~\anaconda3\envs\ml-dl-nlp\lib\site-packages\pandas\_libs\parsers.pyx:852, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~\anaconda3\envs\ml-dl-nlp\lib\site-packages\pandas\_libs\parsers.pyx:1965, in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xbc in position 130: invalid start byte

# %%
for idx in range(1, 11, 1):
    num = f"{idx:02d}"
    fileNm1 = 'C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_2025{}_수원시.csv'.format(num)
    print(fileNm1)
    suwan = pd.read_csv(fileNm1, sep=',')
    suwan_c = suwan[suwan.card_tpbuz_nm_2=='커피/음료']
    fileNm2 = 'C:/data/경기도_카드_소비_데이터/suwan_2025{}.csv'.format(num)
    suwan_c.to_csv(fileNm2)
# Out:
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202501_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202502_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202503_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202504_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202505_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202506_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202507_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202508_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202509_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202510_수원시.csv

# %%
suwan = pd.read_csv('C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202312_수원시.csv', sep=',')

# %%
suwan_c = suwan[suwan.card_tpbuz_nm_2=='커피/음료']
suwan_c.to_csv('C:/data/경기도_카드_소비_데이터/suwan_202312.csv')

# %%
suwan = pd.read_csv('C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202412_수원시.csv', sep=',', encoding='cp949')

# %%
suwan_c = suwan[suwan.card_tpbuz_nm_2=='커피/음료']
suwan_c.to_csv('C:/data/경기도_카드_소비_데이터/suwan_202412.csv')

# %%
import os
from dotenv import load_dotenv
load_dotenv('./../01_python/.env')
pub_key = os.getenv('RAIN_ID')
#print(pub_key)

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import quote
import os
from dotenv import load_dotenv
load_dotenv('./../01_python/.env')
key = os.getenv('RAIN_ID')
bdate='20251223'
btm='1000'
nx='61'
ny='121'
url1 = f'http://apis.data.go.kr/1360000/VilageFcstInfoService_2.0/getUltraSrtNcst?ServiceKey={key}&base_date={bdate}&base_time={btm}&nx={nx}&ny={ny}'
response = requests.get(url1)
soup = BeautifulSoup(response.text, 'xml')
soup
if soup.resultCode.text == '00':
    for item in soup.items:
        if item.category.text == 'T1H':
            print('기온:',item.obsrValue.text)
        if item.category.text == 'RN1':
            print('강수:',item.obsrValue.text)
else:
    print('오류:', soup.resultMsg.text )
# Out:
# 강수: 0
# 기온: 4.4

# %%
import pandas as pd

# %%
# 음식 전체로 작성
chk_yy = '2023'
for idx in range(1, 13):
    num = f"{idx:02d}"
    fileNm1 = 'C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_{}{}_수원시.csv'.format(chk_yy, num)
    print(fileNm1)
    suwan = pd.read_csv(fileNm1, sep=',')
    suwan_c = suwan[suwan.card_tpbuz_nm_1=='음식']
    fileNm2 = 'C:/data/경기도_카드_소비_데이터/suwan_{}{}_음식.csv'.format(chk_yy, num)
    suwan_c.to_csv(fileNm2)
# Out:
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202301_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202302_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202303_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202304_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202305_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202306_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202307_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202308_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202309_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202310_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202311_수원시.csv
# C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202312_수원시.csv

# %%
# 음식 전체로 작성
chk_yy = '2025'
for idx in range(1, 11):
    num = f"{idx:02d}"
    fileNm1 = 'C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_{}{}_수원시.csv'.format(chk_yy, num)
    suwan = pd.read_csv(fileNm1, sep=',')
    suwan_c = suwan[suwan.card_tpbuz_nm_1=='음식']
    fileNm2 = 'C:/data/경기도_카드_소비_데이터/suwan_{}{}_음식.csv'.format(chk_yy, num)
    suwan_c.to_csv(fileNm2)
    print(fileNm2)
# Out:
# C:/data/경기도_카드_소비_데이터/suwan_202501_음식.csv
# C:/data/경기도_카드_소비_데이터/suwan_202502_음식.csv
# C:/data/경기도_카드_소비_데이터/suwan_202503_음식.csv
# C:/data/경기도_카드_소비_데이터/suwan_202504_음식.csv
# C:/data/경기도_카드_소비_데이터/suwan_202505_음식.csv
# C:/data/경기도_카드_소비_데이터/suwan_202506_음식.csv
# C:/data/경기도_카드_소비_데이터/suwan_202507_음식.csv
# C:/data/경기도_카드_소비_데이터/suwan_202508_음식.csv
# C:/data/경기도_카드_소비_데이터/suwan_202509_음식.csv
# C:/data/경기도_카드_소비_데이터/suwan_202510_음식.csv

# %%
suwan = pd.read_csv('C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202412_수원시.csv', sep=',', encoding='cp949')

# %%
suwan_c = suwan[suwan.card_tpbuz_nm_1=='음식']
suwan_c.to_csv('C:/data/경기도_카드_소비_데이터/suwan_202412_음식.csv')

# %%
fileNm1 = 'C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_202301_수원시.csv'
suwan = pd.read_csv(fileNm1, sep=',')

# %%
remove_cols = ["sex", "age"]
suwan = suwan.drop(columns=[c for c in remove_cols if c in suwan.columns])
group_cols = [c for c in suwan.columns if c not in ["amt", "cnt"]]
result_df = (
    suwan
    .groupby(group_cols, as_index=False)
    .agg({
        "amt": "sum",
        "cnt": "sum"
    })
)

# %%
df
# Out:
#            ta_ymd  cty_rgn_no  admi_cty_no card_tpbuz_cd card_tpbuz_nm_1  \
# 0        20230101       41111     41111560           D02           소매/유통
# 1        20230101       41111     41111560           D02           소매/유통
# 2        20230101       41111     41111560           D02           소매/유통
# 3        20230101       41111     41111560           D02           소매/유통
# 4        20230101       41111     41111560           D02           소매/유통
# ...           ...         ...          ...           ...             ...
# 2288324  20230131       41117     41117610           Y04        공공/기업/단체
# 2288325  20230131       41117     41117610           Y04        공공/기업/단체
# 2288326  20230131       41117     41117610           Y04        공공/기업/단체
# 2288327  20230131       41117     41117610           Y04        공공/기업/단체
# 2288328  20230131       41117     41117610           Y04        공공/기업/단체
#
#         card_tpbuz_nm_2  hour  day      amt  cnt
# 0               건강/기호식품     5    7    99502    2
# 1               건강/기호식품     5    7    32338    2
# 2               건강/기호식품     5    7    18284    2
# 3               건강/기호식품     5    7   373134    2
# 4               건강/기호식품     6    7   308458    2
# ...                 ...   ...  ...      ...  ...
# 2288324              단체     6    2  2282303    2
# 2288325              단체     7    2     7900    2
# 2288326              단체     8    2     7900    2
# 2288327              단체     8    2     8603    2
# 2288328              단체     9    2   333567    2
#
# [2288329 rows x 10 columns]

# %%
# 음식 전체로 작성
chk_yy = '2025'
remove_cols = ["sex", "age"]
for idx in range(1, 11):
    num = f"{idx:02d}"
    fileNm1 = 'C:/data/경기도_카드_소비_데이터/suwan/tbsh_gyeonggi_day_{}{}_수원시.csv'.format(chk_yy, num)
    suwan = pd.read_csv(fileNm1, sep=',')
    suwan_c = suwan[suwan.card_tpbuz_nm_1=='음식']
    suwan_c = suwan_c.drop(columns=[c for c in remove_cols if c in suwan_c.columns])
    group_cols = [c for c in suwan_c.columns if c not in ["amt", "cnt"]]
    result_df = (
        suwan_c
        .groupby(group_cols, as_index=False)
        .agg({
            "amt": "sum",
            "cnt": "sum"
        })
    )
    fileNm2 = 'C:/data/경기도_카드_소비_데이터/suwan_C_{}{}_음식.csv'.format(chk_yy, num)
    suwan_c.to_csv(fileNm2)
    print(fileNm2)
