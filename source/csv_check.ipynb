# %%
import pandas as pd

# %%
suwan = pd.read_csv('C:/Users/Admin/Downloads/경기도_카드_소비_데이터/2024/카드 소비 데이터_202410/tbsh_gyeonggi_day_수원시.csv', sep=',')

# %%
pd
suwan_c = suwan[suwan.card_tpbuz_nm_2=='커피/음료']
#suwan

# %%
suwan_c.to_csv('C:/Users/Admin/Downloads/경기도_카드_소비_데이터/2024/카드 소비 데이터_202410/sw_202410.csv')

# %%
suwan1 = pd.read_csv('C:/Users/Admin/Downloads/경기도_카드_소비_데이터/2024/카드 소비 데이터_202410/sw_202410.csv', sep=',')

# %%
suwan1
# Out:
#         Unnamed: 0    ta_ymd  cty_rgn_no  admi_cty_no card_tpbuz_cd  \
# 0             1356  20241001       41111     41111560           Q13
# 1             1357  20241001       41111     41111560           Q13
# 2             1358  20241001       41111     41111560           Q13
# 3             1359  20241001       41111     41111560           Q13
# 4             1360  20241001       41111     41111560           Q13
# ...            ...       ...         ...          ...           ...
# 137367     2516473  20241031       41117     41117610           Q13
# 137368     2516474  20241031       41117     41117610           Q13
# 137369     2516475  20241031       41117     41117610           Q13
# 137370     2516476  20241031       41117     41117610           Q13
# 137371     2516477  20241031       41117     41117610           Q13
#
#        card_tpbuz_nm_1 card_tpbuz_nm_2  hour sex  age  day    amt  cnt
# 0                   음식           커피/음료     1   F    2    2  14557    2
# ...

# %%
suwan = pd.read_csv('C:/Users/Admin/Downloads/경기도_카드_소비_데이터/2024/카드소비 데이터_202401/tbsh_gyeonggi_day_202401_수원시.csv', sep=',')

# %%
suwan_c = suwan[suwan.card_tpbuz_nm_2=='커피/음료']

# %%
suwan_c.to_csv('C:/Users/Admin/Downloads/경기도_카드_소비_데이터/2024/sw_202401.csv')

# %%
card_nm2 = suwan[suwan.card_tpbuz_nm_1=='음식'].groupby('card_tpbuz_nm_2')

# %%
list(card_nm2)
# Out:
# [('간이주점',
#              ta_ymd  cty_rgn_no  admi_cty_no card_tpbuz_cd card_tpbuz_nm_1  \
#   633      20240101       41111     41111560           Q01              음식
#   634      20240101       41111     41111560           Q01              음식
#   635      20240101       41111     41111560           Q01              음식
#   636      20240101       41111     41111560           Q01              음식
#   637      20240101       41111     41111560           Q01              음식
#   ...           ...         ...          ...           ...             ...
#   2418575  20240131       41117     41117610           Q01              음식
#   2418576  20240131       41117     41117610           Q01              음식
#   2418577  20240131       41117     41117610           Q01              음식
#   2418578  20240131       41117     41117610           Q01              음식
#   2418579  20240131       41117     41117610           Q01              음식
#
# ...

# %%
group_names = list(card_nm2.groups.keys())

# %%
group_names
# Out:
# ['간이주점',
#  '고기요리',
#  '닭/오리요리',
#  '별식/퓨전요리',
#  '부페',
#  '분식',
#  '양식',
#  '유흥주점',
#  '음식배달서비스',
#  '일식/수산물',
#  '제과/제빵/떡/케익',
#  '중식',
#  '커피/음료',
#  '패스트푸드',
#  '한식',
#  '휴게소/대형업체']
