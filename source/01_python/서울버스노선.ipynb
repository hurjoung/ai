# %%
import numpy
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_seoul_bus = pd.read_excel('C:/ai/source/01_python/data/서울시버스노선별정류소정보(20251103).xlsx')

# %%
df_seoul_bus.head(10)
# Out:
#     ROUTE_ID    노선명  순번    NODE_ID  ARS_ID              정류소명         X좌표  \
# 0  108900010   도봉02   1  108900216    9500               우이동  127.012290
# 1  110900002   노원11   1  110900001   11511           수락현대아파트  127.060282
# 2  110900006   노원09   1  110900002   11512      서울특별시북부기술교육원  127.057117
# 3  110900007   노원08   1  110900003   11513          상계8동주민센터  127.051943
# 4  110900003   노원05   1  110900004   11514            온곡초등학교  127.066454
# 5  103900010   성동13   1  103900217    4847  옥수역5.6번출구한강버스선착장  127.016998
# 6  112900008  서대문14   1  112900227   13500              정원슈퍼  126.931724
# 7  113900005   마포02   1  113900112   14765               청암대  126.947881
# 8  113900013   마포08   1  113900215   14987          월드컵파크7단지  126.879876
# 9  113900014   마포15   1  113900215   14987          월드컵파크7단지  126.879876
#
#          Y좌표
# 0  37.663431
# 1  37.674636
# 2  37.642161
# 3  37.666974
# 4  37.666715
# 5  37.541854
# 6  37.586436
# 7  37.535827
# 8  37.580411
# 9  37.580411

# %%
plt.figure(figsize=(10,6))
ax = sns.scatterplot(data=df_seoul_bus, x='X좌표', y='Y좌표', hue='노선명')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1,1), fontsize=7)
plt.savefig('data/seoul_bus.png')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2868\4115687015.py:4: UserWarning: Glyph 51340 (\N{HANGUL SYLLABLE JWA}) missing from current font.
#   plt.savefig('data/seoul_bus.png')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2868\4115687015.py:4: UserWarning: Glyph 54364 (\N{HANGUL SYLLABLE PYO}) missing from current font.
#   plt.savefig('data/seoul_bus.png')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2868\4115687015.py:4: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   plt.savefig('data/seoul_bus.png')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2868\4115687015.py:4: UserWarning: Glyph 48393 (\N{HANGUL SYLLABLE BONG}) missing from current font.
#   plt.savefig('data/seoul_bus.png')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2868\4115687015.py:4: UserWarning: Glyph 45432 (\N{HANGUL SYLLABLE NO}) missing from current font.
#   plt.savefig('data/seoul_bus.png')
# ...
